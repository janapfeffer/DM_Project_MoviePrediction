# %% [markdown]
# # Cluster Experiments
# After the data has been prepared (one entry per user with the userId and percentage of each genre he has watched) and transformed (pca, tsne) several clustering algorithms are tried (with hyper parameter tuning).
# The results of the clustering are ealuated visually based on plotting the transformed data and by manually having a look at the average percentage of watched genres in the different clusters.

# %%
# change used width of browser window
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# import packages
import pandas as pd
import re
# import seaborn as sb
import matplotlib.pyplot as plt
# import datetime
# import json
# from sklearn.manifold import TSNE as TSNE
from sklearn.cluster import DBSCAN
# import KMeans
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering

# %%
# pip install https://github.com/scikit-learn-contrib/scikit-learn-extra/archive/master.zip
from sklearn_extra.cluster import KMedoids

# %% [markdown]
# # 1. Load Data

# %%
df_joined = pd.read_csv("userclusterdata.csv")

# %%
df_tsne = pd.read_csv("tsne_allgenres.csv",header=None)
df_pca = pd.read_csv("pca_allgenres.csv",header=None)

# %% [markdown]
# # 2. Cluster Experiments
# # 2.1 KMeans

# %%
# setup a figure
plt.figure(figsize=(10,10))

# iterate over all values that we want to test for K
a = 1
b = 2
for i in range(5,11):
    # create the clusterer
    estimator = KMeans(n_clusters = i)
    
    # create the clustering
#     cluster_ids = estimator.fit_predict(df_joined.drop(columns="userId"))
    clusters = estimator.fit(df_joined.drop(columns="userId"))
    cluster_ids = estimator.predict(df_joined.drop(columns="userId"))

    # add a subplot
    plt.subplot(3,2,a)
    a = a + 1    
    # automatically adjust subplot params so that the subplot(s) fits in to the figure area
    plt.tight_layout()    
    # setup the labels of the subplot
    plt.title("#clusters (K) = {}".format(i) + " SSE: " + str(clusters.inertia_))
    # create the scatter plot
    plt.scatter(df_pca[0],df_pca[1], c=cluster_ids)

     # add a subplot
#     plt.subplot(6,2,b)
#     b = b + 2
#     # automatically adjust subplot params so that the subplot(s) fits in to the figure area
#     plt.tight_layout() 
#     # setup the labels of the subplot
#     plt.title("#clusters (K) = {}".format(i) + " SSE: " + str(clusters.inertia_))
#     # create the scatter plot
#     plt.scatter(df_tsne[0],df_tsne[1], c=cluster_ids)
        
plt.show()

# %% [markdown]
# Let's take a look at the genres in representative clusters:

# %%
# estimator = KMeans(n_clusters = 13)
# cluster_ids = estimator.fit_predict(df_tsne)
# df_joined["clusters"] = cluster_ids
# plt.scatter(df_tsne[0],df_tsne[1], c=cluster_ids) 
# plt.show()

# %%
# for cluster in range(0,13):
#     print("Cluster No " + str(cluster))
#     print("in this cluster: " + str(len(df_joined[df_joined["clusters"] == cluster])/len(df_joined)))
#     display(df_joined[df_joined["clusters"] == cluster].drop(columns=["userId", "clusters"]).describe())

# %%
estimator = KMeans(n_clusters = 13)
cluster_ids = estimator.fit_predict(df_joined.drop(columns="userId"))
df_joined["clusters"] = cluster_ids
plt.scatter(df_tsne[0],df_tsne[1], c=cluster_ids) 
plt.show()

# %%
for cluster in range(0,13):
    print("Cluster No " + str(cluster))
    print("in this cluster: " + str(len(df_joined[df_joined["clusters"] == cluster])/len(df_joined)))
    display(df_joined[df_joined["clusters"] == cluster].drop(columns=["userId", "clusters"]).describe())
# Out:
# Cluster No 0
# in this cluster: 0.22412347174011968
#             Romance         Crime        Horror         Music  \
# count  59596.000000  59596.000000  59596.000000  59596.000000
# mean       0.078163      0.052508      0.081843      0.014245
# std        0.046486      0.041571      0.053320      0.023456
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.054422      0.031250      0.050000      0.000000
# 50%        0.076501      0.049471      0.076389      0.007143
# 75%        0.097619      0.066017      0.109195      0.020261
# max        0.666667      0.750000      0.333333      0.500000
#
#        Science Fiction     Animation      Thriller       History  \
# count     59596.000000  59596.000000  59596.000000  59596.000000
# mean          0.035650      0.013533      0.127731      0.009471
# std           0.033131      0.019323      0.064873      0.019494
# min           0.000000      0.000000      0.000000      0.000000
# 25%           0.010417      0.000000      0.095692      0.000000
# 50%           0.032692      0.007123      0.115842      0.000000
# 75%           0.051149      0.022727      0.143939      0.012500
# max           0.500000      0.500000      1.000000      0.416667
#
#           Adventure         Drama   Documentary        Action       Fantasy  \
# count  59596.000000  59596.000000  59596.000000  59596.000000  59596.000000
# mean       0.038317      0.276617      0.018485      0.056843      0.023025
# std        0.030449      0.049259      0.031032      0.039194      0.027984
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.017857      0.250000      0.000000      0.035714      0.000000
# 50%        0.035714      0.278070      0.000000      0.053431      0.019249
# 75%        0.054233      0.309524      0.029412      0.071429      0.032576
# max        0.333333      0.458333      0.214286      0.500000      0.500000
#
#             Foreign       Western       Mystery        Comedy        Family  \
# count  59596.000000  59596.000000  59596.000000  59596.000000  59596.000000
# mean       0.009816      0.004846      0.041156      0.090365      0.015166
# std        0.018487      0.018903      0.049545      0.042474      0.020395
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.017403      0.067619      0.000000
# 50%        0.003922      0.000000      0.034420      0.100000      0.010870
# 75%        0.011494      0.000000      0.051282      0.121314      0.022727
# max        0.266667      0.500000      0.666667      0.250000      0.333333
#
#                 War      TV Movie
# count  59596.000000  59596.000000
# mean       0.011882      0.000340
# std        0.021400      0.003761
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.003546      0.000000
# 75%        0.015873      0.000000
# max        0.333333      0.250000
# Cluster No 1
# in this cluster: 0.34254833456810085
#             Romance         Crime        Horror         Music  \
# count  91086.000000  91086.000000  91086.000000  91086.000000
# mean       0.078702      0.048528      0.053281      0.014956
# std        0.031575      0.024383      0.029380      0.015982
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.063025      0.037356      0.038462      0.004866
# 50%        0.077463      0.047222      0.052995      0.013314
# 75%        0.091085      0.057502      0.066667      0.019938
# max        0.555556      0.416667      0.300000      0.350000
#
#        Science Fiction     Animation      Thriller       History  \
# count     91086.000000  91086.000000  91086.000000  91086.000000
# mean          0.027674      0.010875      0.086104      0.010753
# std           0.018652      0.012565      0.027829      0.012663
# min           0.000000      0.000000      0.000000      0.000000
# 25%           0.017857      0.000000      0.073238      0.000000
# 50%           0.026733      0.009009      0.086217      0.009390
# 75%           0.035606      0.015628      0.100379      0.014583
# max           0.333333      0.333333      0.312500      0.333333
#
#           Adventure         Drama   Documentary        Action       Fantasy  \
# count  91086.000000  91086.000000  91086.000000  91086.000000  91086.000000
# mean       0.035386      0.275731      0.035281      0.053077      0.024667
# std        0.020234      0.032772      0.030759      0.023984      0.018310
# min        0.000000      0.166667      0.000000      0.000000      0.000000
# 25%        0.023804      0.254365      0.013889      0.041667      0.015625
# 50%        0.033403      0.274769      0.031250      0.053360      0.023629
# 75%        0.044261      0.296970      0.048780      0.063492      0.030952
# max        0.277778      0.400000      0.200000      0.344444      0.375000
#
#             Foreign       Western       Mystery        Comedy        Family  \
# count  91086.000000  91086.000000  91086.000000  91086.000000  91086.000000
# mean       0.010718      0.007074      0.031694      0.161078      0.020383
# std        0.012753      0.013333      0.020806      0.021519      0.017087
# min        0.000000      0.000000      0.000000      0.041667      0.000000
# 25%        0.002381      0.000000      0.020739      0.146667      0.010417
# 50%        0.008390      0.001258      0.028747      0.162176      0.019608
# 75%        0.014387      0.010309      0.039954      0.176316      0.026923
# max        0.277778      0.333333      0.333333      0.250000      0.316667
#
#                 War      TV Movie
# count  91086.000000  91086.000000
# mean       0.013436      0.000602
# std        0.014075      0.002777
# min        0.000000      0.000000
# 25%        0.004938      0.000000
# 50%        0.011111      0.000000
# 75%        0.017083      0.000000
# max        0.250000      0.250000
# Cluster No 2
# in this cluster: 0.012312575449311225
#            Romance        Crime       Horror        Music  Science Fiction  \
# count  3274.000000  3274.000000  3274.000000  3274.000000      3274.000000
# mean      0.033989     0.019111     0.007806     0.008581         0.004466
# std       0.063990     0.050232     0.033804     0.033700         0.021351
# min       0.000000     0.000000     0.000000     0.000000         0.000000
# 25%       0.000000     0.000000     0.000000     0.000000         0.000000
# 50%       0.000000     0.000000     0.000000     0.000000         0.000000
# 75%       0.055556     0.000000     0.000000     0.000000         0.000000
# max       0.333333     0.333333     0.333333     0.277778         0.250000
#
#          Animation     Thriller      History    Adventure        Drama  \
# count  3274.000000  3274.000000  3274.000000  3274.000000  3274.000000
# mean      0.000974     0.033409     0.006325     0.007555     0.755308
# std       0.009884     0.061657     0.028428     0.026983     0.160487
# min       0.000000     0.000000     0.000000     0.000000     0.527778
# 25%       0.000000     0.000000     0.000000     0.000000     0.625000
# 50%       0.000000     0.000000     0.000000     0.000000     0.666667
# 75%       0.000000     0.054924     0.000000     0.000000     1.000000
# max       0.250000     0.333333     0.250000     0.250000     1.000000
#
#        Documentary      Action      Fantasy      Foreign      Western  \
# count  3274.000000  3274.00000  3274.000000  3274.000000  3274.000000
# mean      0.003625     0.03664     0.006649     0.006468     0.001930
# std       0.025319     0.06494     0.028585     0.027891     0.016063
# min       0.000000     0.00000     0.000000     0.000000     0.000000
# 25%       0.000000     0.00000     0.000000     0.000000     0.000000
# 50%       0.000000     0.00000     0.000000     0.000000     0.000000
# 75%       0.000000     0.06250     0.000000     0.000000     0.000000
# max       0.400000     0.25000     0.333333     0.250000     0.250000
#
#            Mystery       Comedy       Family          War     TV Movie
# count  3274.000000  3274.000000  3274.000000  3274.000000  3274.000000
# mean      0.008650     0.047767     0.005528     0.004921     0.000297
# std       0.030861     0.079392     0.025266     0.022593     0.006151
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.083333     0.000000     0.000000     0.000000
# max       0.250000     0.375000     0.250000     0.222222     0.166667
# Cluster No 3
# in this cluster: 0.1397180217143588
#             Romance         Crime        Horror         Music  \
# count  37152.000000  37152.000000  37152.000000  37152.000000
# mean       0.084338      0.044468      0.031226      0.015212
# std        0.077385      0.061666      0.046168      0.040269
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.037037      0.000000      0.000000      0.000000
# 50%        0.075000      0.033333      0.000000      0.000000
# 75%        0.111111      0.062500      0.050000      0.015152
# max        0.500000      0.666667      0.333333      0.500000
#
#        Science Fiction     Animation      Thriller       History  \
# count     37152.000000  37152.000000  37152.000000  37152.000000
# mean          0.017580      0.006413      0.078940      0.012136
# std           0.029198      0.018670      0.072309      0.034496
# min           0.000000      0.000000      0.000000      0.000000
# 25%           0.000000      0.000000      0.031250      0.000000
# 50%           0.000000      0.000000      0.072917      0.000000
# 75%           0.029167      0.000000      0.111111      0.010870
# max           0.500000      0.500000      0.500000      0.500000
#
#           Adventure         Drama   Documentary        Action       Fantasy  \
# count  37152.000000  37152.000000  37152.000000  37152.000000  37152.000000
# mean       0.026900      0.417235      0.017776      0.050641      0.017391
# std        0.037588      0.057204      0.038748      0.054570      0.035244
# min        0.000000      0.291667      0.000000      0.000000      0.000000
# 25%        0.000000      0.372527      0.000000      0.000000      0.000000
# 50%        0.017544      0.405070      0.000000      0.041667      0.000000
# 75%        0.041667      0.458333      0.000000      0.071429      0.025641
# max        0.500000      0.611111      0.300000      0.444444      0.500000
#
#             Foreign       Western       Mystery        Comedy        Family  \
# count  37152.000000  37152.000000  37152.000000  37152.000000  37152.000000
# mean       0.012185      0.004773      0.026771      0.106652      0.013636
# std        0.033638      0.022710      0.040459      0.070804      0.031086
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.062500      0.000000
# 50%        0.000000      0.000000      0.005635      0.110000      0.000000
# 75%        0.010989      0.000000      0.041667      0.150000      0.017544
# max        0.500000      0.500000      0.500000      0.400000      0.500000
#
#                 War      TV Movie
# count  37152.000000  37152.000000
# mean       0.015284      0.000441
# std        0.034237      0.004799
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.020833      0.000000
# max        0.500000      0.250000
# Cluster No 4
# in this cluster: 0.06633522246499717
#             Romance         Crime        Horror         Music  \
# count  17639.000000  17639.000000  17639.000000  17639.000000
# mean       0.075949      0.060299      0.068465      0.019988
# std        0.061204      0.073868      0.065476      0.037245
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.033333      0.000000      0.000000      0.000000
# 50%        0.069444      0.047619      0.055556      0.000000
# 75%        0.108333      0.083333      0.111111      0.031250
# max        0.500000      1.000000      0.333333      0.666667
#
#        Science Fiction     Animation      Thriller       History  \
# count     17639.000000  17639.000000  17639.000000  17639.000000
# mean          0.038116      0.012033      0.098018      0.011961
# std           0.053020      0.028641      0.074126      0.026272
# min           0.000000      0.000000      0.000000      0.000000
# 25%           0.000000      0.000000      0.050000      0.000000
# 50%           0.025641      0.000000      0.088745      0.000000
# 75%           0.055556      0.014706      0.128205      0.012821
# max           0.750000      0.500000      0.666667      0.500000
#
#           Adventure         Drama   Documentary        Action       Fantasy  \
# count  17639.000000  17639.000000  17639.000000  17639.000000  17639.000000
# mean       0.048894      0.138212      0.024951      0.084011      0.038432
# std        0.041593      0.055758      0.043283      0.070722      0.049557
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.111111      0.000000      0.041667      0.000000
# 50%        0.046078      0.152778      0.000000      0.072917      0.027778
# 75%        0.074561      0.177459      0.043478      0.111111      0.055556
# max        0.321429      0.255556      0.200000      0.500000      0.666667
#
#             Foreign       Western       Mystery        Comedy        Family  \
# count  17639.000000  17639.000000  17639.000000  17639.000000  17639.000000
# mean       0.012735      0.010662      0.038054      0.171440      0.033739
# std        0.027982      0.036013      0.048582      0.068296      0.043175
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.125000      0.000000
# 50%        0.000000      0.000000      0.027778      0.166667      0.022222
# 75%        0.012845      0.000000      0.055556      0.220000      0.052083
# max        0.333333      0.500000      1.000000      0.375000      0.333333
#
#                 War      TV Movie
# count  17639.000000  17639.000000
# mean       0.013484      0.000557
# std        0.025261      0.005697
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.022222      0.000000
# max        0.500000      0.166667
# Cluster No 5
# in this cluster: 0.00462943811182105
#            Romance        Crime       Horror        Music  Science Fiction  \
# count  1231.000000  1231.000000  1231.000000  1231.000000      1231.000000
# mean      0.146899     0.007585     0.007294     0.006000         0.006564
# std       0.204410     0.032831     0.036374     0.031394         0.031395
# min       0.000000     0.000000     0.000000     0.000000         0.000000
# 25%       0.000000     0.000000     0.000000     0.000000         0.000000
# 50%       0.000000     0.000000     0.000000     0.000000         0.000000
# 75%       0.250000     0.000000     0.000000     0.000000         0.000000
# max       0.500000     0.250000     0.333333     0.250000         0.250000
#
#          Animation     Thriller      History    Adventure        Drama  \
# count  1231.000000  1231.000000  1231.000000  1231.000000  1231.000000
# mean      0.003082     0.008390     0.000884     0.008574     0.029090
# std       0.020104     0.031962     0.009335     0.031224     0.064575
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000
# max       0.250000     0.333333     0.166667     0.166667     0.250000
#
#        Documentary       Action      Fantasy      Foreign      Western  \
# count  1231.000000  1231.000000  1231.000000  1231.000000  1231.000000
# mean      0.003273     0.011087     0.005900     0.002182     0.001043
# std       0.028498     0.038226     0.027163     0.018646     0.012624
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000
# max       0.333333     0.250000     0.250000     0.250000     0.250000
#
#            Mystery       Comedy       Family          War     TV Movie
# count  1231.000000  1231.000000  1231.000000  1231.000000  1231.000000
# mean      0.004115     0.734732     0.009736     0.003379     0.000192
# std       0.021574     0.207772     0.034669     0.021745     0.004765
# min       0.000000     0.500000     0.000000     0.000000     0.000000
# 25%       0.000000     0.500000     0.000000     0.000000     0.000000
# 50%       0.000000     0.666667     0.000000     0.000000     0.000000
# 75%       0.000000     1.000000     0.000000     0.000000     0.000000
# max       0.250000     1.000000     0.250000     0.166667     0.125000
# Cluster No 6
# in this cluster: 0.1112494217903252
#             Romance         Crime        Horror         Music  \
# count  29582.000000  29582.000000  29582.000000  29582.000000
# mean       0.076940      0.043944      0.036725      0.015505
# std        0.051161      0.037589      0.040672      0.027589
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.047251      0.019048      0.000000      0.000000
# 50%        0.071429      0.040080      0.028986      0.000000
# 75%        0.099799      0.060847      0.055556      0.022222
# max        0.500000      0.500000      0.333333      0.500000
#
#        Science Fiction     Animation      Thriller       History  \
# count     29582.000000  29582.000000  29582.000000  29582.000000
# mean          0.019925      0.007962      0.067773      0.009434
# std           0.025122      0.016780      0.043092      0.018120
# min           0.000000      0.000000      0.000000      0.000000
# 25%           0.000000      0.000000      0.040230      0.000000
# 50%           0.014706      0.000000      0.067762      0.000000
# 75%           0.031250      0.011111      0.092593      0.012821
# max           0.333333      0.333333      0.333333      0.261905
#
#           Adventure         Drama   Documentary        Action       Fantasy  \
# count  29582.000000  29582.000000  29582.000000  29582.000000  29582.000000
# mean       0.030065      0.276297      0.029882      0.044457      0.021905
# std        0.028000      0.050604      0.040231      0.034879      0.027722
# min        0.000000      0.130556      0.000000      0.000000      0.000000
# 25%        0.006803      0.239764      0.000000      0.020015      0.000000
# 50%        0.026471      0.272147      0.000000      0.041667      0.016667
# 75%        0.043290      0.312500      0.051282      0.062500      0.033159
# max        0.250000      0.444444      0.222222      0.333333      0.500000
#
#             Foreign       Western       Mystery        Comedy        Family  \
# count  29582.000000  29582.000000  29582.000000  29582.000000  29582.000000
# mean       0.011009      0.005783      0.032525      0.234202      0.021493
# std        0.018697      0.020039      0.032564      0.031351      0.028507
# min        0.000000      0.000000      0.000000      0.166667      0.000000
# 25%        0.000000      0.000000      0.000000      0.209793      0.000000
# 50%        0.000000      0.000000      0.027778      0.228070      0.013889
# 75%        0.016264      0.000000      0.048485      0.250000      0.033333
# max        0.250000      0.500000      0.416667      0.357143      0.333333
#
#                 War      TV Movie
# count  29582.000000  29582.000000
# mean       0.013515      0.000661
# std        0.020811      0.005646
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.020833      0.000000
# max        0.250000      0.250000
# Cluster No 7
# in this cluster: 0.021071276799783382
#            Romance        Crime       Horror        Music  Science Fiction  \
# count  5603.000000  5603.000000  5603.000000  5603.000000      5603.000000
# mean      0.055624     0.044577     0.032981     0.014583         0.020781
# std       0.056662     0.051799     0.057601     0.037772         0.036824
# min       0.000000     0.000000     0.000000     0.000000         0.000000
# 25%       0.000000     0.000000     0.000000     0.000000         0.000000
# 50%       0.047619     0.033333     0.000000     0.000000         0.000000
# 75%       0.083333     0.069444     0.041667     0.000000         0.037037
# max       0.500000     0.500000     0.333333     0.500000         0.416667
#
#          Animation     Thriller      History    Adventure        Drama  \
# count  5603.000000  5603.000000  5603.000000  5603.000000  5603.000000
# mean      0.005959     0.065219     0.008754     0.035072     0.213229
# std       0.024734     0.061693     0.027648     0.040831     0.090439
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.166667
# 50%       0.000000     0.060606     0.000000     0.025641     0.214286
# 75%       0.000000     0.104167     0.000000     0.062500     0.266667
# max       0.500000     0.500000     0.416667     0.333333     0.500000
#
#        Documentary       Action      Fantasy      Foreign      Western  \
# count  5603.000000  5603.000000  5603.000000  5603.000000  5603.000000
# mean      0.229001     0.037960     0.024353     0.012903     0.006542
# std       0.064001     0.052351     0.038657     0.037825     0.030929
# min       0.125000     0.000000     0.000000     0.000000     0.000000
# 25%       0.181818     0.000000     0.000000     0.000000     0.000000
# 50%       0.208333     0.000000     0.000000     0.000000     0.000000
# 75%       0.250000     0.066667     0.041667     0.000000     0.000000
# max       0.500000     0.333333     0.333333     0.416667     0.333333
#
#            Mystery       Comedy       Family          War     TV Movie
# count  5603.000000  5603.000000  5603.000000  5603.000000  5603.000000
# mean      0.044016     0.112453     0.012883     0.022754     0.000356
# std       0.054437     0.080253     0.030865     0.034252     0.005089
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.055556     0.000000     0.000000     0.000000
# 50%       0.032407     0.111111     0.000000     0.000000     0.000000
# 75%       0.071429     0.166667     0.000000     0.041667     0.000000
# max       0.500000     0.416667     0.312500     0.333333     0.166667
# Cluster No 8
# in this cluster: 0.04171759299303892
#             Romance         Crime        Horror         Music  \
# count  11093.000000  11093.000000  11093.000000  11093.000000
# mean       0.077281      0.037597      0.028075      0.019133
# std        0.082852      0.063252      0.053091      0.053097
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000
# 50%        0.062500      0.000000      0.000000      0.000000
# 75%        0.116667      0.055556      0.041667      0.000000
# max        0.500000      0.500000      0.333333      0.500000
#
#        Science Fiction     Animation      Thriller       History  \
# count     11093.000000  11093.000000  11093.000000  11093.000000
# mean          0.015936      0.006979      0.042412      0.007705
# std           0.039987      0.026690      0.054395      0.022708
# min           0.000000      0.000000      0.000000      0.000000
# 25%           0.000000      0.000000      0.000000      0.000000
# 50%           0.000000      0.000000      0.025641      0.000000
# 75%           0.009615      0.000000      0.071429      0.000000
# max           0.500000      0.333333      0.500000      0.333333
#
#           Adventure         Drama   Documentary        Action       Fantasy  \
# count  11093.000000  11093.000000  11093.000000  11093.000000  11093.000000
# mean       0.022102      0.211067      0.013643      0.040010      0.020053
# std        0.037279      0.120033      0.040643      0.056879      0.044906
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.136646      0.000000      0.000000      0.000000
# 50%        0.000000      0.200000      0.000000      0.022222      0.000000
# 75%        0.037037      0.275758      0.000000      0.066216      0.027778
# max        0.500000      0.500000      0.333333      0.500000      0.500000
#
#             Foreign       Western       Mystery        Comedy        Family  \
# count  11093.000000  11093.000000  11093.000000  11093.000000  11093.000000
# mean       0.009657      0.005426      0.021492      0.383220      0.029417
# std        0.032262      0.026846      0.045470      0.071708      0.059806
# min        0.000000      0.000000      0.000000      0.250000      0.000000
# 25%        0.000000      0.000000      0.000000      0.333333      0.000000
# 50%        0.000000      0.000000      0.000000      0.361111      0.000000
# 75%        0.000000      0.000000      0.031250      0.437500      0.041667
# max        0.500000      0.500000      0.500000      0.666667      0.500000
#
#                 War      TV Movie
# count  11093.000000  11093.000000
# mean       0.008129      0.000666
# std        0.024547      0.007464
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.000000      0.000000
# max        0.500000      0.333333
# Cluster No 9
# in this cluster: 0.017017227827774373
#            Romance        Crime       Horror        Music  Science Fiction  \
# count  4525.000000  4525.000000  4525.000000  4525.000000      4525.000000
# mean      0.037730     0.022346     0.424786     0.011183         0.019145
# std       0.064036     0.055808     0.188210     0.040982         0.058317
# min       0.000000     0.000000     0.166667     0.000000         0.000000
# 25%       0.000000     0.000000     0.333333     0.000000         0.000000
# 50%       0.000000     0.000000     0.333333     0.000000         0.000000
# 75%       0.066667     0.000000     0.500000     0.000000         0.000000
# max       0.500000     0.500000     1.000000     0.500000         0.500000
#
#          Animation     Thriller      History    Adventure        Drama  \
# count  4525.000000  4525.000000  4525.000000  4525.000000  4525.000000
# mean      0.004595     0.141112     0.006085     0.025893     0.134151
# std       0.024769     0.144174     0.028702     0.056204     0.119090
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.111111     0.000000     0.000000     0.133333
# 75%       0.000000     0.250000     0.000000     0.000000     0.250000
# max       0.333333     0.750000     0.333333     0.500000     0.500000
#
#        Documentary       Action     Fantasy      Foreign      Western  \
# count  4525.000000  4525.000000  4525.00000  4525.000000  4525.000000
# mean      0.007865     0.035513     0.02497     0.008502     0.003618
# std       0.044054     0.068029     0.07031     0.031122     0.026593
# min       0.000000     0.000000     0.00000     0.000000     0.000000
# 25%       0.000000     0.000000     0.00000     0.000000     0.000000
# 50%       0.000000     0.000000     0.00000     0.000000     0.000000
# 75%       0.000000     0.055556     0.00000     0.000000     0.000000
# max       0.500000     0.500000     0.50000     0.277778     0.500000
#
#            Mystery       Comedy       Family          War     TV Movie
# count  4525.000000  4525.000000  4525.000000  4525.000000  4525.000000
# mean      0.020568     0.049552     0.009340     0.012786     0.000260
# std       0.055663     0.088881     0.032513     0.037017     0.004555
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.083333     0.000000     0.000000     0.000000
# max       0.500000     0.500000     0.277778     0.333333     0.125000
# Cluster No 10
# in this cluster: 0.0028656635590638834
#           Romance       Crime      Horror       Music  Science Fiction  \
# count  762.000000  762.000000  762.000000  762.000000       762.000000
# mean     0.000146    0.016149    0.000437    0.000328         0.000620
# std      0.004025    0.061013    0.006963    0.009057         0.010686
# min      0.000000    0.000000    0.000000    0.000000         0.000000
# 25%      0.000000    0.000000    0.000000    0.000000         0.000000
# 50%      0.000000    0.000000    0.000000    0.000000         0.000000
# 75%      0.000000    0.000000    0.000000    0.000000         0.000000
# max      0.111111    0.250000    0.111111    0.250000         0.250000
#
#        Animation    Thriller     History   Adventure       Drama  Documentary  \
# count      762.0  762.000000  762.000000  762.000000  762.000000        762.0
# mean         0.0    0.000766    0.000146    0.001750    0.500583          0.0
# std          0.0    0.010091    0.004025    0.020413    0.005842          0.0
# min          0.0    0.000000    0.000000    0.000000    0.500000          0.0
# 25%          0.0    0.000000    0.000000    0.000000    0.500000          0.0
# 50%          0.0    0.000000    0.000000    0.000000    0.500000          0.0
# 75%          0.0    0.000000    0.000000    0.000000    0.500000          0.0
# max          0.0    0.166667    0.111111    0.250000    0.583333          0.0
#
#            Action     Fantasy     Foreign     Western     Mystery      Comedy  \
# count  762.000000  762.000000  762.000000  762.000000  762.000000  762.000000
# mean     0.474993    0.001094    0.000729    0.001312    0.000328    0.000292
# std      0.074883    0.014551    0.010631    0.018077    0.009057    0.005864
# min      0.222222    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.500000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.500000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.500000    0.000000    0.000000    0.000000    0.000000    0.000000
# max      0.500000    0.250000    0.222222    0.250000    0.250000    0.138889
#
#        Family         War  TV Movie
# count   762.0  762.000000     762.0
# mean      0.0    0.000328       0.0
# std       0.0    0.009057       0.0
# min       0.0    0.000000       0.0
# 25%       0.0    0.000000       0.0
# 50%       0.0    0.000000       0.0
# 75%       0.0    0.000000       0.0
# max       0.0    0.250000       0.0
# Cluster No 11
# in this cluster: 0.0026362600458054884
#           Romance       Crime      Horror       Music  Science Fiction  \
# count  701.000000  701.000000  701.000000  701.000000       701.000000
# mean     0.025141    0.019868    0.011892    0.018569         0.006188
# std      0.063478    0.074282    0.046284    0.081931         0.036010
# min      0.000000    0.000000    0.000000    0.000000         0.000000
# 25%      0.000000    0.000000    0.000000    0.000000         0.000000
# 50%      0.000000    0.000000    0.000000    0.000000         0.000000
# 75%      0.000000    0.000000    0.000000    0.000000         0.000000
# max      0.250000    0.500000    0.250000    0.500000         0.500000
#
#         Animation    Thriller     History   Adventure       Drama  \
# count  701.000000  701.000000  701.000000  701.000000  701.000000
# mean     0.002262    0.026737    0.004997    0.010651    0.067719
# std      0.020512    0.067324    0.042075    0.041446    0.100365
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.000000    0.000000    0.166667
# max      0.250000    0.500000    0.500000    0.250000    0.333333
#
#        Documentary      Action     Fantasy     Foreign     Western  \
# count   701.000000  701.000000  701.000000  701.000000  701.000000
# mean      0.645038    0.019684    0.008845    0.011493    0.001866
# std       0.221671    0.058103    0.041500    0.066118    0.020005
# min       0.400000    0.000000    0.000000    0.000000    0.000000
# 25%       0.500000    0.000000    0.000000    0.000000    0.000000
# 50%       0.500000    0.000000    0.000000    0.000000    0.000000
# 75%       1.000000    0.000000    0.000000    0.000000    0.000000
# max       1.000000    0.250000    0.500000    0.500000    0.333333
#
#           Mystery      Comedy      Family         War    TV Movie
# count  701.000000  701.000000  701.000000  701.000000  701.000000
# mean     0.049440    0.056905    0.005570    0.006899    0.000238
# std      0.132971    0.122787    0.032016    0.037730    0.006295
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.000000    0.000000    0.000000
# max      0.500000    0.500000    0.250000    0.500000    0.166667
# Cluster No 12
# in this cluster: 0.013775492935500006
#            Romance        Crime       Horror        Music  Science Fiction  \
# count  3663.000000  3663.000000  3663.000000  3663.000000      3663.000000
# mean      0.117707     0.017810     0.022710     0.020942         0.051837
# std       0.131800     0.043493     0.052044     0.070846         0.105309
# min       0.000000     0.000000     0.000000     0.000000         0.000000
# 25%       0.000000     0.000000     0.000000     0.000000         0.000000
# 50%       0.097222     0.000000     0.000000     0.000000         0.000000
# 75%       0.166667     0.000000     0.000000     0.000000         0.066667
# max       1.000000     0.500000     0.266667     1.000000         1.000000
#
#          Animation     Thriller      History    Adventure        Drama  \
# count  3663.000000  3663.000000  3663.000000  3663.000000  3663.000000
# mean      0.027834     0.031891     0.009649     0.160979     0.098204
# std       0.100765     0.058957     0.030665     0.113337     0.090591
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.083333     0.000000
# 50%       0.000000     0.000000     0.000000     0.166667     0.111111
# 75%       0.000000     0.050000     0.000000     0.222222     0.166667
# max       1.000000     0.500000     0.333333     1.000000     0.277778
#
#        Documentary       Action      Fantasy      Foreign      Western  \
# count  3663.000000  3663.000000  3663.000000  3663.000000  3663.000000
# mean      0.006459     0.112668     0.061827     0.013071     0.022735
# std       0.026141     0.122146     0.112773     0.042079     0.103169
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.083333     0.000000     0.000000     0.000000
# 75%       0.000000     0.177778     0.083333     0.000000     0.000000
# max       0.200000     1.000000     1.000000     0.500000     1.000000
#
#            Mystery       Comedy       Family          War     TV Movie
# count  3663.000000  3663.000000  3663.000000  3663.000000  3663.000000
# mean      0.016753     0.054740     0.053117     0.068729     0.000307
# std       0.049932     0.075492     0.094783     0.104052     0.006749
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.097817     0.083333     0.111111     0.000000
# max       0.500000     0.333333     0.666667     0.500000     0.333333

# %% [markdown]
# # 2.2 KMedoids
# Unable to run KMedoids on all data. BUT
# - we don't have real outliers anyways
# - the clusters with a sample of 10.000 of the data don't look too different from KMeans with all data
# -> KMeans is the better choice

# %%
# setup a figure
plt.figure(figsize=(10,10))

# iterate over all values that we want to test for K
a = 1
for i in range(5,11):
    # create the clusterer
    estimator = KMedoids(metric="euclidean", n_clusters=i)
    
    # create the clustering
#     cluster_ids = estimator.fit_predict(df_joined.drop(columns="userId"))
    clusters = estimator.fit(df_joined.drop(columns="userId").head(10000))
    cluster_ids = estimator.predict(df_joined.drop(columns="userId").head(10000))

    # add a subplot
    plt.subplot(3,2,a)
    a = a + 1
    
    # automatically adjust subplot params so that the subplot(s) fits in to the figure area
    plt.tight_layout() 
    
    # setup the labels of the subplot
    plt.title("#clusters (K) = {}".format(i) + " SSE: " + str(clusters.inertia_))
#     plt.xlabel('ItemsBought')
#     plt.ylabel('ItemsReturned')
    
    # create the scatter plot
    plt.scatter(df_pca.head(10000)[0],df_pca.head(10000)[1], c=cluster_ids)
#     plt.scatter(df_tsne[0],df_tsne[1], c=cluster_ids)
        
plt.show()

# %% [markdown]
# # 2.3 Agglomerative Clustering
# unable to run with all data, but it doesn't work well with linkage=single anyways.
# works well with linkage=ward, BUT since its not possible to run it on all data and the difference to kmeans doesn't appear to be very large we prefer kmeans

# %%
# setup a figure
plt.figure(figsize=(10,10))

# iterate over all values that we want to test for K
a = 1
for i in range(5,11):
    # create the clusterer
    estimator = AgglomerativeClustering(n_clusters = i, linkage='ward', affinity='euclidean')
    
    # create the clustering
#     cluster_ids = estimator.fit_predict(df_joined.drop(columns="userId"))
#     clusters = estimator.fit(df_tsne)
    cluster_ids = estimator.fit_predict(df_joined.drop(columns="userId").head(10000))

    # add a subplot
    plt.subplot(3,2,a)
    a = a + 1
    
    # automatically adjust subplot params so that the subplot(s) fits in to the figure area
    plt.tight_layout() 
    
    # setup the labels of the subplot
    plt.title("#clusters (K) = {}".format(i))
#     plt.xlabel('ItemsBought')
#     plt.ylabel('ItemsReturned')
    
    # create the scatter plot
    plt.scatter(df_pca[0].head(10000),df_pca[1].head(10000), c=cluster_ids)
#     plt.scatter(df_tsne.head(10000)[0],df_tsne.head(10000)[1], c=cluster_ids)
        
plt.show()

# %% [markdown]
# ## 2.4 DBSCAN
# doesn't work well on a subset of the data, unable to run on all data

# %%
# create the clusterer
clusterer = DBSCAN(min_samples=25, eps=0.02, metric='cosine')
# create the clusters
clusters = clusterer.fit(df_joined.drop(columns="userId").head(10000))

plt.scatter(df_pca.head(10000)[0],df_pca.head(10000)[1] ,c=clusters.labels_)
plt.show()
